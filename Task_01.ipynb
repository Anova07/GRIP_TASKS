# %% [markdown]
# <a href="https://colab.research.google.com/github/Anova07/GRIP_TASKS/blob/main/Task_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TASK 1: GRIP_JULY21**

# %% [markdown]
# #**Prediction using Supervised ML**

# %% [markdown]
# #By Anova Pandey

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Predict the percentage of an student based on the no. of study hours.

# %% [markdown]
# # Importing all libraries required in this notebook

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Reading data from remote link

# %%
url = "http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Data imported successfully")

s_data.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# # Plotting the distribution of scores

# %%
s_data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# From the graph above, we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score.

# %% [markdown]
# # Preparing the data
# The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
X = s_data.iloc[:, :-1].values  
y = s_data.iloc[:, 1].values

# %% [markdown]
# Splitting the data into training and test sets. this by using Scikit-Learn's built-in train_test_split() method:

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("TRAINING COMPLETED")
# Out:
# TRAINING COMPLETED

# %% [markdown]
# # Plotting the regression line

# %%
line = regressor.coef_*X+regressor.intercept_
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# #Making Predictions

# %%
print(X_test) # Testing data - In Hours
y_pred = regressor.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %% [markdown]
# # Comparing Actual vs Predicted

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# # Estimating training and test score

# %%
print(" Training Score;",regressor.score(X_train,y_train))
print("Test Score:", regressor.score(X_test,y_test))
# Out:
#  Training Score; 0.9515510725211553
# Test Score: 0.9454906892105354

# %% [markdown]
# # Plotting the bar graph to depict the difference between the actual and predicted values

# %%
df.plot(kind='bar',figsize=(5,5))
plt.grid(which='major', linewidth='0.5', color = 'red')
plt.grid(which='minor', linewidth='0.5', color = 'blue')
plt.show()

# %% [markdown]
# #Testing the model with our own data

# %%
hours = 9.25
test = np.array([hours])
test = test.reshape(-1,1)
own_pred = regressor.predict(test)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# #Evaluating the model

# %%
from sklearn import metrics 
print("Mean Absolute Error:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error:",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("R-2:", metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
# Mean Squared Error: 21.598769307217456
# Root Mean Squared Error: 4.647447612100373
# R-2: 0.9454906892105354

# %% [markdown]
# #          THANK YOU
#
# ---
